# %%
# split
import os
import xml.dom.minidom
import xml.etree.ElementTree as ET
directory = "./annotations"
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
#         doc = xml.dom.minidom.parse(f)
#         tags = doc.getElementsByTagName("name")
        f = open(f, "r")
        print(f.read())
        annotation = (ET.parse(f).getroot().findall("annotation"))
        name = [x.find('object').text for x in annotation]
        #print(name)
    
    
        #print(tags)
# Out:
# <annotation>
#     <folder>images</folder>
#     <filename>road712.png</filename>
#     <size>
#         <width>300</width>
#         <height>400</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>speedlimit</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>98</xmin>
#             <ymin>140</ymin>
#             <xmax>139</xmax>
#             <ymax>182</ymax>
#         </bndbox>
#     </object>
#     <object>
#         <name>speedlimit</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <occluded>0</occluded>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>97</xmin>
#             <ymin>205</ymin>
#             <xmax>138</xmax>
#             <ymax>246</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ...

# %%
import xml.etree.ElementTree as ETree
import pandas as pd

for filename in os.listdir(directory):
    #f = os.path.join(directory, filename)
    #if os.path.isfile(f):
    xmlpath = directory + '/' + filename
    tree = ETree.parse(xmlpath)
    root = tree.getroot()

    for storeno in root.iter('object'):
        name = storeno.attrib.get('name')
        print(name)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
# split
import os
import shutil
directory = "./annotations/"
for filename in os.listdir(directory):
    print(filename)
    f = open(directory+filename, "r")
    content = f.read()
    if "speedlimit" in content:
        break
#         source = "./images/"+filename[:-4]+".png"
#         shutil.move(source, "./speed_limit/")
    elif "trafficlight" in content:
        break
#         source = "./images/"+filename[:-4]+".png"
#         shutil.move(source, "./traffic_light/")
    elif "crosswalk" in content:
        break
#         source = "./images/"+filename[:-4]+".png"
#         shutil.move(source, "./crosswalk/")
    elif "stop" in content:
        break
#         source = "./images/"+filename[:-4]+".png"
#         shutil.move(source, "./stop_sign/")
# Out:
# road712.xml

# %%
totalFiles = 0
images_dir = "./images/traffic_light"
# images_dir = keras.utils.get_file(myFile, 'file://'+fullPath)
image_count = len(list(images_dir))
totalFiles += (len(os.listdir(images_dir)))

images_dir = "./images/speed_limit"
# images_dir = keras.utils.get_file(myFile, 'file://'+fullPath)
image_count = len(list(images_dir))
totalFiles += (len(os.listdir(images_dir)))

images_dir = "./images/stop_sign"
# images_dir = keras.utils.get_file(myFile, 'file://'+fullPath)
image_count = len(list(images_dir))
totalFiles += (len(os.listdir(images_dir)))

images_dir = "./images/crosswalk"
# images_dir = keras.utils.get_file(myFile, 'file://'+fullPath)
image_count = len(list(images_dir))
totalFiles += (len(os.listdir(images_dir)))

print(totalFiles)
# Out:
# 877

# %%
import tensorflow as tf
images_dir = "./images/"
train_ds = tf.keras.utils.image_dataset_from_directory(
  images_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
